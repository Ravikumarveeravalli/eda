# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\Ravi Kumar\Downloads\Iris.csv")

# %%
datac=data.copy()

# %%
datac.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# here i got to know that in this data set we have around 150 flowers

# %%
datac.shape
# Out:
# (150, 6)

# %%
datac["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
datac["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
# our data set is balanced dataset based on species column

# %%
datac.drop(["Id"],axis=1,inplace=True)

# %%
datac.describe() # descriptive statsics of your datser
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
datac.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
datac.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
for y in datac.columns[:4]:
    print(y)
# Out:
# SepalLengthCm
# SepalWidthCm
# PetalLengthCm
# PetalWidthCm

# %%
for y in datac.columns[:4]:
    x=np.percentile(datac[y],[25,50,75])
    q1=x[0]
    q2=x[1]
    q3=x[2]
    iqr=q3-q1
    lb=q1-(1.5*iqr)
    ub=q3+(1.5*iqr)
    print(y)
    print(len(data.loc[datac[y]<lb])+len(data.loc[datac[y]>ub]))
    print("-------------------------------------------------------")
# Out:
# SepalLengthCm
# 0
# -------------------------------------------------------
# SepalWidthCm
# 4
# -------------------------------------------------------
# PetalLengthCm
# 0
# -------------------------------------------------------
# PetalWidthCm
# 0
# -------------------------------------------------------

# %%
import seaborn as sns

# %%
sns.boxplot()
# Out:
# <AxesSubplot:>

# %%
datac.boxplot()
# Out:
# <AxesSubplot:>

# %%
datac
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(datac["SepalLengthCm"],datac["SepalWidthCm"])
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("sl vs sw")
# Out:
# Text(0.5, 1.0, 'sl vs sw')

# %%
plt.plot(datac["SepalLengthCm"],datac["SepalWidthCm"],linestyle="--")
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("sl vs sw")
# Out:
# Text(0.5, 1.0, 'sl vs sw')

# %%
plt.plot(datac["SepalLengthCm"],datac["SepalWidthCm"],linestyle="",marker="+")
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("sl vs sw")
# Out:
# Text(0.5, 1.0, 'sl vs sw')

# %%
plt.plot(datac["SepalLengthCm"],datac["SepalWidthCm"],linestyle="",marker="o")
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("sl vs sw")
# Out:
# Text(0.5, 1.0, 'sl vs sw')

# %%
plt.plot(datac["SepalLengthCm"],datac["SepalWidthCm"],linestyle="--",marker="o")
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("sl vs sw")
# Out:
# Text(0.5, 1.0, 'sl vs sw')

# %%
plt.plot(datac["SepalLengthCm"],datac["SepalWidthCm"],linestyle="--",marker="o",color="r")
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("sl vs sw")
# Out:
# Text(0.5, 1.0, 'sl vs sw')

# %%
plt.plot(datac["SepalLengthCm"],datac["SepalWidthCm"],linestyle="--",marker="o",color="g")
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("sl vs sw")
# Out:
# Text(0.5, 1.0, 'sl vs sw')

# %%
plt.plot(datac["SepalLengthCm"],datac["SepalWidthCm"],linestyle="--",marker="o",color="r",markersize=7)
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("sl vs sw")
# Out:
# Text(0.5, 1.0, 'sl vs sw')

# %%
plt.plot(datac["SepalLengthCm"],datac["SepalWidthCm"],linestyle="--",marker="o",color="r",markersize=3)
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("sl vs sw")
# Out:
# Text(0.5, 1.0, 'sl vs sw')

# %%
plt.plot(datac["SepalLengthCm"],datac["SepalWidthCm"],linestyle="--",marker="o",color="r",markersize=10)
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("sl vs sw")
# Out:
# Text(0.5, 1.0, 'sl vs sw')

# %%
datac.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
datac.loc[datac["Species"]=="Iris-setosa"]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0             5.1           3.5            1.4           0.2  Iris-setosa
# 1             4.9           3.0            1.4           0.2  Iris-setosa
# 2             4.7           3.2            1.3           0.2  Iris-setosa
# 3             4.6           3.1            1.5           0.2  Iris-setosa
# 4             5.0           3.6            1.4           0.2  Iris-setosa
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa
# 11            4.8           3.4            1.6           0.2  Iris-setosa
# ...

# %%
datac["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
setosa=datac.loc[datac["Species"]=="Iris-setosa"]
versicolor=datac.loc[datac["Species"]=="Iris-versicolor"]
verginica=datac.loc[datac["Species"]=="Iris-verginica"]

# %%
plt.plot(setosa["PetalLengthCm"],setosa["PetalWidthCm"],linestyle=" ",marker="d",color="g",markersize="7",label="setosa")
plt.plot(versicolor["PetalLengthCm"],versicolor["PetalWidthCm"],linestyle=" ",marker="d",color="k",markersize="7",label="versicolor")
plt.plot(verginica["PetalLengthCm"],verginica["PetalWidthCm"],linestyle=" ",marker="d",color="b",markersize="7",label="virginica")
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
plt.title("sl vs sw")
plt.legend()

# %%
datac["Species"].unique()

# %%
setosa=datac.loc[datac["Species"]=="Iris-setosa"]
versicolor=datac.loc[datac["Species"]=="Iris-versicolor"]
verginica=datac.loc[datac["Species"]=="Iris-verginica"]

# %%
plt.plot(setosa["SepalLengthCm"],setosa["SepalWidthCm"],linestyle=" ",marker="d",color="g",markersize="7",label="setosa")
plt.plot(versicolor["SepalLengthCm"],versicolor["SepalWidthCm"],linestyle=" ",marker="d",color="k",markersize="7",label="versicolor")
plt.plot(verginica["SepalLengthCm"],verginica["SepalWidthCm"],linestyle=" ",marker="d",color="b",markersize="7",label="virginica")
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("sl vs sw")
plt.legend()

# %% [markdown]
# # scatter()

# %%
plt.scatter(datac["SepalLengthCm"],datac["SepalWidthCm"])

# %%
sns.scatterplot(data=datac,x="SepalLengthCm",y="SepalWidthCm",hue="Species")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.scatterplot(data=datac,x="SepalLengthCm",y="PetalWidthCm",hue="Species")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.scatterplot(data=datac,x="PetalLengthCm",y="PetalWidthCm",hue="Species")
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.distplot(datac["PetalLengthCm"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>

# %%
setosa=datac.loc[datac["Species"]=="Iris-setosa"]
versicolor=datac.loc[datac["Species"]=="Iris-versicolor"]
verginica=datac.loc[datac["Species"]=="Iris-verginica"]

# %%
sns.distplot(setosa["PetalLengthCm"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.distplot(setosa["PetalWidthCm"])
sns.distplot(versicolor["PetalWidthCm"])
sns.distplot(verginica["PetalWidthCm"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.distplot(setosa["SepalWidthCm"])
sns.distplot(versicolor["SepalWidthCm"])
sns.distplot(verginica["SepalWidthCm"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.distplot(setosa["SepalLengthCm"])
sns.distplot(versicolor["SepalLengthCm"])
sns.distplot(verginica["SepalLengthCm"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.distplot(setosa["PetalLengthCm"])
sns.distplot(versicolor["PetalLengthCm"])
sns.distplot(verginica["PetalLengthCm"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # displot()

# %%
sns.displot(data=datac,x="PetalWidthCm",hue="Species")

# %%
sns.displot(datac["PetalWidthCm"],kind="kde")

# %%
sns.displot(datac["SepalLengthCm"],kind="kde")

# %%
sns.displot(data=datac,x="PetalWidthCm",hue="Species",kind="kde")

# %%
datac.head
# Out:
# <bound method NDFrame.head of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# ...

# %%
datac["Species"].unique
# Out:
# <bound method Series.unique of 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object>

# %%
datac["Species"]=datac["Species"].map({"Iris-setosa":0,"Iris-versicolor":1,"Iris-virginica":2})

# %%
datac["Species"].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
datac["Species"].unique
# Out:
# <bound method Series.unique of 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64>

# %%
datac["SepalLengthCm"].apply(int)
# Out:
# 0      5
# 1      4
# 2      4
# 3      4
# 4      5
#       ..
# 145    6
# 146    6
# 147    6
# 148    6
# 149    5
# Name: SepalLengthCm, Length: 150, dtype: int64

# %%
datac["SepalLengthCm"].apply(complex)
# Out:
# 0      5.1+0.0j
# 1      4.9+0.0j
# 2      4.7+0.0j
# 3      4.6+0.0j
# 4      5.0+0.0j
#          ...
# 145    6.7+0.0j
# 146    6.3+0.0j
# 147    6.5+0.0j
# 148    6.2+0.0j
# 149    5.9+0.0j
# Name: SepalLengthCm, Length: 150, dtype: complex128

# %%
datac["SepalWidthCm"].apply(int)
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 145    3
# 146    2
# 147    3
# 148    3
# 149    3
# Name: SepalWidthCm, Length: 150, dtype: int64

# %%
def sq(x):
    return x**2

# %%
datac["SepalLengthCm"].apply(sq)
# Out:
# 0      26.01
# 1      24.01
# 2      22.09
# 3      21.16
# 4      25.00
#        ...
# 145    44.89
# 146    39.69
# 147    42.25
# 148    38.44
# 149    34.81
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
datac["SepalWidthCm"].apply(sq)
# Out:
# 0      12.25
# 1       9.00
# 2      10.24
# 3       9.61
# 4      12.96
#        ...
# 145     9.00
# 146     6.25
# 147     9.00
# 148    11.56
# 149     9.00
# Name: SepalWidthCm, Length: 150, dtype: float64

# %%
datac[["SepalWidthCm"]]
# Out:
#      SepalWidthCm
# 0             3.5
# 1             3.0
# 2             3.2
# 3             3.1
# 4             3.6
# ..            ...
# 145           3.0
# 146           2.5
# 147           3.0
# 148           3.4
# 149           3.0
#
# [150 rows x 1 columns]

# %%
datac[["SepalWidthCm"]].apply(sum,axis=1)
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Length: 150, dtype: float64

# %% [markdown]
# # applymap is a data frame function

# %%
datac[["SepalLengthCm","SepalWidthCm"]].applymap(type)
# Out:
#        SepalLengthCm     SepalWidthCm
# 0    <class 'float'>  <class 'float'>
# 1    <class 'float'>  <class 'float'>
# 2    <class 'float'>  <class 'float'>
# 3    <class 'float'>  <class 'float'>
# 4    <class 'float'>  <class 'float'>
# ..               ...              ...
# 145  <class 'float'>  <class 'float'>
# 146  <class 'float'>  <class 'float'>
# 147  <class 'float'>  <class 'float'>
# 148  <class 'float'>  <class 'float'>
# 149  <class 'float'>  <class 'float'>
#
# [150 rows x 2 columns]

# %%
datac[["Species"]].applymap(type)
# Out:
#            Species
# 0    <class 'int'>
# 1    <class 'int'>
# 2    <class 'int'>
# 3    <class 'int'>
# 4    <class 'int'>
# ..             ...
# 145  <class 'int'>
# 146  <class 'int'>
# 147  <class 'int'>
# 148  <class 'int'>
# 149  <class 'int'>
#
# [150 rows x 1 columns]

# %%
datac=pd.DataFrame({"Name":["Ravi kumar","Hemanth kumar","Raj kumar"]})

# %%
datac
# Out:
#             Name
# 0     Ravi kumar
# 1  Hemanth kumar
# 2      Raj kumar

# %%
datac["Name"].str.split()
# Out:
# 0       [Ravi, kumar]
# 1    [Hemanth, kumar]
# 2        [Raj, kumar]
# Name: Name, dtype: object

# %%
# how to handle missing values (nan),unnces values and outliers

# %%
# outlies --to find out the outliers

# %%
# trim -deleteing 
# cap - filling

# %%
data=pd.read_csv(r"C:\Users\Ravi Kumar\Downloads\new_csv1.csv")

# %%
data
# Out:
#   Name   Age Gender  Height  Weight
# 0   p1  23.0      m   154.0    43.0
# 1   p2  21.0      f   123.0    34.0
# 2   p3   NaN    NaN     NaN     NaN
# 3   p4  24.0      m   145.0    12.0
# 4   p5   NaN      m   135.0     NaN
# 5   p6  12.0    NaN   124.0    45.0

# %%
data.isnull().sum()
# Out:
# Name      0
# Age       2
# Gender    2
# Height    1
# Weight    2
# dtype: int64

# %%
----
<5 null values -- capp it
>40 50 -- drop the column
# Out:
#   File "C:\Users\Ravi Kumar\AppData\Local\Temp\ipykernel_25676\2604870757.py", line 1
#     ----
#         ^
# SyntaxError: invalid syntax

# %%
data.isnull().mean()*100
# Out:
# Name       0.000000
# Age       33.333333
# Gender    33.333333
# Height    16.666667
# Weight    33.333333
# dtype: float64

# %%
-- mean,median,mode
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25676\586467149.py in <module>
# ----> 1 -- mean,median,mode
#
# NameError: name 'mean' is not defined

# %%
data.fillna({"Age":1,"Gender":"no","Height":12,"Weight":100})
# Out:
#   Name   Age Gender  Height  Weight
# 0   p1  23.0      m   154.0    43.0
# 1   p2  21.0      f   123.0    34.0
# 2   p3   1.0     no    12.0   100.0
# 3   p4  24.0      m   145.0    12.0
# 4   p5   1.0      m   135.0   100.0
# 5   p6  12.0     no   124.0    45.0

# %%
data["Age"].mean()
# Out:
# 20.0

# %%
data.fillna({"Age":data["Age"].mean(),"Gender":"no","Height":data["Height"].median(),"Weight":data["Weight"].median()})
# Out:
#   Name   Age Gender  Height  Weight
# 0   p1  23.0      m   154.0    43.0
# 1   p2  21.0      f   123.0    34.0
# 2   p3  20.0     no   135.0    38.5
# 3   p4  24.0      m   145.0    12.0
# 4   p5  20.0      m   135.0    38.5
# 5   p6  12.0     no   124.0    45.0

# %%
data["Gender"].mode()
# Out:
# 0    m
# Name: Gender, dtype: object

# %%
data.fillna(method="ffill",limit=2)
# Out:
#   Name   Age Gender  Height  Weight
# 0   p1  23.0      m   154.0    43.0
# 1   p2  21.0      f   123.0    34.0
# 2   p3  21.0      f   123.0    34.0
# 3   p4  24.0      m   145.0    12.0
# 4   p5  24.0      m   135.0    12.0
# 5   p6  12.0      m   124.0    45.0

# %%
data.head()
# Out:
#   Name   Age Gender  Height  Weight
# 0   p1  23.0      m   154.0    43.0
# 1   p2  21.0      f   123.0    34.0
# 2   p3   NaN    NaN     NaN     NaN
# 3   p4  24.0      m   145.0    12.0
# 4   p5   NaN      m   135.0     NaN

# %%
data.dropna()
# Out:
#   Name   Age Gender  Height  Weight
# 0   p1  23.0      m   154.0    43.0
# 1   p2  21.0      f   123.0    34.0
# 3   p4  24.0      m   145.0    12.0

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Height', 'Weight'], dtype='object')

# %%
data.columns[1:]
# Out:
# Index(['Age', 'Gender', 'Height', 'Weight'], dtype='object')

# %%
data.columns[1]
# Out:
# 'Age'

# %%
datac=data[data.columns[1:]]

# %%
datac
# Out:
#     Age Gender  Height  Weight
# 0  23.0      m   154.0    43.0
# 1  21.0      f   123.0    34.0
# 2   NaN    NaN     NaN     NaN
# 3  24.0      m   145.0    12.0
# 4   NaN      m   135.0     NaN
# 5  12.0    NaN   124.0    45.0

# %%
datac.dropna(how="all")
# Out:
#     Age Gender  Height  Weight
# 0  23.0      m   154.0    43.0
# 1  21.0      f   123.0    34.0
# 3  24.0      m   145.0    12.0
# 4   NaN      m   135.0     NaN
# 5  12.0    NaN   124.0    45.0

# %%
# thresh---- non null values

# %%
datac.dropna(thresh=1)

# minimum have two values it will not remove
# Out:
#     Age Gender  Height  Weight
# 0  23.0      m   154.0    43.0
# 1  21.0      f   123.0    34.0
# 3  24.0      m   145.0    12.0
# 4   NaN      m   135.0     NaN
# 5  12.0    NaN   124.0    45.0

# %%
datac.dropna(thresh=2)
# Out:
#     Age Gender  Height  Weight
# 0  23.0      m   154.0    43.0
# 1  21.0      f   123.0    34.0
# 3  24.0      m   145.0    12.0
# 4   NaN      m   135.0     NaN
# 5  12.0    NaN   124.0    45.0

# %%
datac.dropna(thresh=3)
# Out:
#     Age Gender  Height  Weight
# 0  23.0      m   154.0    43.0
# 1  21.0      f   123.0    34.0
# 3  24.0      m   145.0    12.0
# 5  12.0    NaN   124.0    45.0

# %%
datac.dropna(thresh=4)
# Out:
#     Age Gender  Height  Weight
# 0  23.0      m   154.0    43.0
# 1  21.0      f   123.0    34.0
# 3  24.0      m   145.0    12.0

# %%
# replace

# %%
data=pd.read_csv(r"C:\Users\Ravi Kumar\Downloads\new_csv1 (1).csv")

# %%
data
# Out:
#   Name  Age Gender    Height Weight
# 0   p1   23      m       154     43
# 1   p2   21      f  19999999     34
# 2   p3   hi     23         m      f
# 3   p4   24      m       145     12
# 4   p5  NaN      m       135    NaN
# 5   p6   12    NaN       124     45

# %%
data.replace({"Age":"hi","Gender":"23","Height":["19999999","m"]},np.nan)

# it will be replaced as nan by using dictionary
# Out:
#   Name  Age Gender Height Weight
# 0   p1   23      m    154     43
# 1   p2   21      f    NaN     34
# 2   p3  NaN    NaN    NaN      f
# 3   p4   24      m    145     12
# 4   p5  NaN      m    135    NaN
# 5   p6   12    NaN    124     45

# %%
data.replace({"Age":"hi","Gender":"23","Height":["19999999","m"]},0)
# Out:
#   Name  Age Gender Height Weight
# 0   p1   23      m    154     43
# 1   p2   21      f      0     34
# 2   p3    0      0      0      f
# 3   p4   24      m    145     12
# 4   p5  NaN      m    135    NaN
# 5   p6   12    NaN    124     45

# %%
import numpy as np

# %%
data.fillna(10)
# Out:
#   Name Age Gender    Height Weight
# 0   p1  23      m       154     43
# 1   p2  21      f  19999999     34
# 2   p3  hi     23         m      f
# 3   p4  24      m       145     12
# 4   p5  10      m       135     10
# 5   p6  12     10       124     45

# %%
data.set_index("Name",inplace=True)

# remove index order

# %%
data
# Out:
#       Age Gender    Height Weight
# Name
# p1     23      m       154     43
# p2     21      f  19999999     34
# p3     hi     23         m      f
# p4     24      m       145     12
# p5    NaN      m       135    NaN
# p6     12    NaN       124     45

# %%
data.index
# Out:
# Index(['p1', 'p2', 'p3', 'p4', 'p5', 'p6'], dtype='object', name='Name')

# %%
data.reset_index(inplace=True)

# reset indexing inplace

# %%
data
# Out:
#   Name  Age Gender    Height Weight
# 0   p1   23      m       154     43
# 1   p2   21      f  19999999     34
# 2   p3   hi     23         m      f
# 3   p4   24      m       145     12
# 4   p5  NaN      m       135    NaN
# 5   p6   12    NaN       124     45

# %%
data.set_index("Gender",inplace=True)

# %%
data
# Out:
#        Name  Age    Height Weight
# Gender
# m        p1   23       154     43
# f        p2   21  19999999     34
# 23       p3   hi         m      f
# m        p4   24       145     12
# m        p5  NaN       135    NaN
# NaN      p6   12       124     45

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#   Gender Name  Age    Height Weight
# 0      m   p1   23       154     43
# 1      f   p2   21  19999999     34
# 2     23   p3   hi         m      f
# 3      m   p4   24       145     12
# 4      m   p5  NaN       135    NaN
# 5    NaN   p6   12       124     45

# %%
data=pd.read_csv(r"C:\Users\Ravi Kumar\Downloads\Iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.bar(data["Species"].unique(),data["Species"].value_counts())
# Out:
# <BarContainer object of 3 artists>

# %%
sns.barplot(data["Species"].unique(),data["Species"].value_counts())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='Species'>

# %%
plt.figure(figsize=(10,10),facecolor="blue")
sns.barplot(data["Species"].unique(),data["Species"].value_counts())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='Species'>
